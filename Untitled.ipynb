# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'inter.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets
import sys
import numpy as np
import cv2


def button1(self):
        iml=cv2.imread("imL.png")
        imr=cv2.imread("imR.png")
        iml=cv2.cvtColor(iml,cv2.COLOR_BGR2GRAY)
        imr=cv2.cvtColor(imr,cv2.COLOR_BGR2GRAY)
        
        stereo = cv2.StereoBM_create(numDisparities = 64, blockSize = 9)
        
        
        
        
        
        disparity=stereo.compute(iml,imr)
        #cv2.imshow("disparity",disparity)
        norm_image = cv2.normalize(disparity, None, alpha = 0, beta = 1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
        cv2.imshow('norm_image', norm_image)


        
def button2(self):
    img=cv2.imread("ncc_img.jpg")
    im2=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    tmp=cv2.imread("ncc_template.jpg",1)
    cv2.imshow("im",img)
    tmp=cv2.cvtColor(tmp,cv2.COLOR_BGR2GRAY)
    res = cv2.matchTemplate(im2,tmp,cv2.TM_CCOEFF_NORMED)
    threshold=0.93
    loc=np.where(res>threshold)
    w, h = tmp.shape[::-1]
    for pt in zip(*loc[::-1]): 
        cv2.rectangle(img, pt, (pt[0] + w, pt[1] + h), (7,249,151), 2)
    cv2.imshow("im",img)
   #

def button3(self):
    img1=cv2.imread("Aerial1.jpg")
    img2=cv2.imread("Aerial2.jpg")
    
    im1=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
    im2=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    
    sift=cv2.xfeatures2d.SIFT_create()
    
    kp1, des1 = sift.detectAndCompute(im1,None)
    kp2, des2 = sift.detectAndCompute(im2,None)
    
    print(kp1[0].response)
    kp1 = sorted(kp1, key=lambda x: x.size,reverse=True)
    kp2 = sorted(kp2, key=lambda x: x.size,reverse=True)
    img=cv2.drawKeypoints(im1,kp1[:6],img1)
    cv2.imshow("img",img)
    
    img2=cv2.drawKeypoints(im2,kp2[:6],img2)
    cv2.imshow("img2",img2)
    

def button4(self):
    img1=cv2.imread("Aerial1.jpg")
    img2=cv2.imread("Aerial2.jpg")
    
    im1=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
    im2=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    
    sift=cv2.xfeatures2d.SIFT_create()
    
    kp1, des1 = sift.detectAndCompute(im1,None)
    kp2, des2 = sift.detectAndCompute(im2,None)
    
    print(kp1[0].response)
    kp1 = sorted(kp1, key=lambda x: x.size,reverse=True)
    kp2 = sorted(kp2, key=lambda x: x.size,reverse=True)
    img1=cv2.drawKeypoints(im1,kp1[:6],img1)
    img2=cv2.drawKeypoints(im2,kp2[:6],img2)

    key1=[]
    key2=[]
    for i in kp1[0:6]:
        key1.append(i)
        
    for i in kp2[0:6]:
        key2.append(i)
    bf = cv2.BFMatcher()
    
    matches = bf.knnMatch(des1, des2,k=2)
    good = []
    for m,n in matches:
        if m.distance < 0.75*n.distance:
            good.append([m])
    
    #matches=sorted(matches,key=lambda x:x.size,reverse=True)
    img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2,good[:6],None,flags=2)
    cv2.imshow("img3",img3)
    
    
    
class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(921, 692)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.pushButton = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton.setGeometry(QtCore.QRect(70, 120, 161, 91))
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_2.setGeometry(QtCore.QRect(60, 420, 171, 91))
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton_3 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_3.setGeometry(QtCore.QRect(600, 170, 171, 71))
        self.pushButton_3.setObjectName("pushButton_3")
        self.pushButton_4 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_4.setGeometry(QtCore.QRect(600, 300, 171, 71))
        self.pushButton_4.setObjectName("pushButton_4")
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 921, 25))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

        
    
       
        
        '''
         max_disp/=2;
            if(max_disp%16!=0)
                max_disp += 16-(max_disp%16);
            resize(left ,left_for_matcher ,Size(),0.5,0.5, INTER_LINEAR_EXACT);
            resize(right,right_for_matcher,Size(),0.5,0.5, INTER_LINEAR_EXACT);
        '''
        
        
    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.pushButton.setText(_translate("MainWindow", "1.1 disparity"))
        self.pushButton_2.setText(_translate("MainWindow", "2.1 NCC"))
        self.pushButton_3.setText(_translate("MainWindow", "3.1 keypoint"))
        self.pushButton_4.setText(_translate("MainWindow", "3.2 matched point"))
        self.pushButton.clicked.connect(button1)
        self.pushButton_2.clicked.connect(button2)
        self.pushButton_3.clicked.connect(button3)
        self.pushButton_4.clicked.connect(button4)

        
        
app = QtWidgets.QApplication(sys.argv)
MainWindow = QtWidgets.QMainWindow()
ui = Ui_MainWindow()

ui.setupUi(MainWindow) 
MainWindow.show()
sys.exit(app.exec_())
# Out:
# 0.05968961864709854
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2889: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
